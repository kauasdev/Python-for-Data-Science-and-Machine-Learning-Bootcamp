# %%
import pandas as pd

# %%
pd.read_csv('example')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df = pd.read_csv('example')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
# df.to_excel('teste.xlsx')

# %%
df.to_csv('output.csv')

# %%
pd.read_csv('output.csv')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_csv('output.csv', index=False)

# %%
pd.read_csv('output.csv')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.read_excel('Excel_Sample.xlsx')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_excel('excel_sample2.xlsx', sheet_name="Sheet1")

# %%
pd.read_excel('excel_sample2.xlsx',)
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
pd.read_excel('excel_sample2.xlsx', index_col=0, header=0)
# para não aparecer a coluna 'Unnamed: 0'
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
data = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
len(data)
# Out:
# 1

# %%
data[0]
# Out:
#                          Bank NameBank           CityCity StateSt  CertCert  \
# 0                    Almena State Bank             Almena      KS     15426
# 1           First City Bank of Florida  Fort Walton Beach      FL     16748
# 2                 The First State Bank      Barboursville      WV     14361
# 3                   Ericson State Bank            Ericson      NE     18265
# 4     City National Bank of New Jersey             Newark      NJ     21111
# ..                                 ...                ...     ...       ...
# 558                 Superior Bank, FSB           Hinsdale      IL     32646
# 559                Malta National Bank              Malta      OH      6629
# 560    First Alliance Bank & Trust Co.         Manchester      NH     34264
# 561  National State Bank of Metropolis         Metropolis      IL      3815
# 562                   Bank of Honolulu           Honolulu      HI     21029
#
# ...

# %%
data[0].columns
# Out:
# Index(['Bank NameBank', 'CityCity', 'StateSt', 'CertCert',
#        'Acquiring InstitutionAI', 'Closing DateClosing', 'FundFund'],
#       dtype='object')

# %%
data[0].columns = ['Bank Name', 'City', 'State', 'Cert', 'Acquiring Institution',
                  'Closing Date', 'Fund']

# %%
data[0].head()
# Out:
#                           Bank Name               City State   Cert  \
# 0                 Almena State Bank             Almena    KS  15426
# 1        First City Bank of Florida  Fort Walton Beach    FL  16748
# 2              The First State Bank      Barboursville    WV  14361
# 3                Ericson State Bank            Ericson    NE  18265
# 4  City National Bank of New Jersey             Newark    NJ  21111
#
#         Acquiring Institution       Closing Date   Fund
# 0                 Equity Bank   October 23, 2020  10538
# 1   United Fidelity Bank, fsb   October 16, 2020  10537
# 2              MVB Bank, Inc.      April 3, 2020  10536
# 3  Farmers and Merchants Bank  February 14, 2020  10535
# 4             Industrial Bank   November 1, 2019  10534

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_sql('my_table', engine)
# Out:
# 4

# %%
sqldf = pd.read_sql('my_table', con=engine)

# %%
sqldf
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15
