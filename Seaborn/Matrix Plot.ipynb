# %% [markdown]
#  # Matrix Plots
#
# Matrix plots allow you to plot data as color-encoded matrices and can also be used to indicate clusters within the data (later in the machine learning section we will learn how to formally cluster data).
#
# Let's begin by exploring seaborn's heatmap and clutermap:

# %%
import seaborn as sns
# %matplotlib inline

# %%
flights = sns.load_dataset('flights')
tips = sns.load_dataset('tips')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Heatmap
#
# In order for a heatmap to work properly, your data should already be in a matrix form, the sns.heatmap function basically just colors it in for you. For example:

# %%
tips.corr()
# exibe a correlação entre as variaveis
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tips_correlation = tips.corr()
tips_correlation
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
import numpy as np


arr = np.array(tips_correlation)
print(arr)
# Out:
# [[1.         0.67573411 0.59831513]
#  [0.67573411 1.         0.48929878]
#  [0.59831513 0.48929878 1.        ]]

# %%
sns.heatmap(tips_correlation)
# Out:
# <Axes: >

# %%
sns.heatmap(tips_correlation, annot=True)
# exibe os valores numéricos pertencentes a cada célula
# Out:
# <Axes: >

# %%
sns.heatmap(tips_correlation, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights[flights['passengers'] == flights['passengers'].max()]
# Out:
#      year month  passengers
# 138  1960   Jul         622

# %%
flights.pivot_table(values='passengers', index='month', columns='year')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
pvtflights = flights.pivot_table(
    values='passengers',
    index='month',
    columns='year'
)

# %%
import numpy as np

# %%
mtx = np.array(flights)
print(mtx)
# Out:
# [[1949 'Jan' 112]
#  [1949 'Feb' 118]
#  [1949 'Mar' 132]
#  [1949 'Apr' 129]
#  [1949 'May' 121]
#  [1949 'Jun' 135]
#  [1949 'Jul' 148]
#  [1949 'Aug' 148]
#  [1949 'Sep' 136]
#  [1949 'Oct' 119]
#  [1949 'Nov' 104]
#  [1949 'Dec' 118]
#  [1950 'Jan' 115]
#  [1950 'Feb' 126]
#  [1950 'Mar' 141]
#  [1950 'Apr' 135]
#  [1950 'May' 125]
#  [1950 'Jun' 149]
#  [1950 'Jul' 170]
#  [1950 'Aug' 170]
#  [1950 'Sep' 158]
#  [1950 'Oct' 133]
#  [1950 'Nov' 114]
#  [1950 'Dec' 140]
#  [1951 'Jan' 145]
#  [1951 'Feb' 150]
#  [1951 'Mar' 178]
#  [1951 'Apr' 163]
#  [1951 'May' 172]
#  [1951 'Jun' 178]
#  [1951 'Jul' 199]
#  [1951 'Aug' 199]
#  [1951 'Sep' 184]
#  [1951 'Oct' 162]
#  [1951 'Nov' 146]
#  [1951 'Dec' 166]
#  [1952 'Jan' 171]
#  [1952 'Feb' 180]
#  [1952 'Mar' 193]
#  [1952 'Apr' 181]
#  [1952 'May' 183]
#  [1952 'Jun' 218]
#  [1952 'Jul' 230]
#  [1952 'Aug' 242]
#  [1952 'Sep' 209]
#  [1952 'Oct' 191]
#  [1952 'Nov' 172]
#  [1952 'Dec' 194]
#  [1953 'Jan' 196]
#  [1953 'Feb' 196]
# ...

# %%
sns.heatmap(pvtflights)
# cmap = 'magma'
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(pvtflights, cmap='coolwarm')
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(pvtflights, linecolor='green', lw=2)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(pvtflights, annot=True)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## clustermap
#
# The clustermap uses hierarchal clustering to produce a clustered version of the heatmap. For example:

# %%
sns.clustermap(pvtflights)

# %% [markdown]
# Notice now how the years and months are no longer in order, instead they are grouped by similarity in value (passenger count). That means we can begin to infer things from this plot, such as August and July being similar (makes sense, since they are both summer travel months)

# %%
sns.clustermap(pvtflights, cmap='coolwarm', standard_scale=0)

# %%
sns.clustermap(pvtflights, cmap='coolwarm', standard_scale=1)

# %%
sns.clustermap(pvtflights, row_cluster=False)
