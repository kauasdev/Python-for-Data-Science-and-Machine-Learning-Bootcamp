# %%
# !pip install chart_studio
# Out:
# Requirement already satisfied: chart_studio in /home/kauas/anaconda3/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: plotly in /home/kauas/anaconda3/lib/python3.10/site-packages (from chart_studio) (5.14.0)
# Requirement already satisfied: six in /home/kauas/anaconda3/lib/python3.10/site-packages (from chart_studio) (1.16.0)
# Requirement already satisfied: retrying>=1.3.3 in /home/kauas/anaconda3/lib/python3.10/site-packages (from chart_studio) (1.3.4)
# Requirement already satisfied: requests in /home/kauas/anaconda3/lib/python3.10/site-packages (from chart_studio) (2.28.1)
# Requirement already satisfied: packaging in /home/kauas/anaconda3/lib/python3.10/site-packages (from plotly->chart_studio) (23.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/kauas/anaconda3/lib/python3.10/site-packages (from plotly->chart_studio) (8.2.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/kauas/anaconda3/lib/python3.10/site-packages (from requests->chart_studio) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/kauas/anaconda3/lib/python3.10/site-packages (from requests->chart_studio) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/kauas/anaconda3/lib/python3.10/site-packages (from requests->chart_studio) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kauas/anaconda3/lib/python3.10/site-packages (from requests->chart_studio) (2022.12.7)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from chart_studio.plotly import iplot

# %matplotlib inline

# %%
customers = pd.read_csv('Ecommerce Customers')

# %%
customers.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
customers.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
sns.set_palette('pastel')
sns.set_style('whitegrid')

# %%
sns.jointplot(
    data=customers,
    x='Time on Website',
    y='Yearly Amount Spent'
)

# %%
sns.jointplot(
    data=customers,
    x='Time on App',
    y='Length of Membership',
    kind='hex'
)

# %%
sns.pairplot(customers)

# %%
sns.lmplot(
    data=customers,
    x='Length of Membership',
    y='Yearly Amount Spent',
)

# %%
X = customers[['Avg. Session Length','Time on App','Time on Website','Length of Membership']]
y = customers['Yearly Amount Spent']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=.3, random_state=101
)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
preds = lm.predict(X_test)

# %%
X_test.shape
# Out:
# (150, 4)

# %%
preds.shape
# Out:
# (150,)

# %%
plt.scatter(y_test, preds)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
print(f"""
MAE: {mean_absolute_error(y_test, preds)}
MSE: {mean_squared_error(y_test, preds)}
RMSE: {np.sqrt(mean_squared_error(y_test, preds))}
""")
# Out:
# MAE: 7.22814865343083
# MSE: 79.81305165097446
# RMSE: 8.933815066978633

# %%
X.columns
# Out:
# Index(['Avg. Session Length', 'Time on App', 'Time on Website',
#        'Length of Membership'],
#       dtype='object')

# %%
pd.DataFrame(
    columns=['Coeffecient'],
    data=lm.coef_,
    index=X.columns
)
# Out:
#                       Coeffecient
# Avg. Session Length     25.981550
# Time on App             38.590159
# Time on Website          0.190405
# Length of Membership    61.279097
